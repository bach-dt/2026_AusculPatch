# %%
import pandas as pd

# %%
a = pd.read_csv('DATASET/all.csv')
for i in range(len(a)):
    a.loc[i, 'file'] = str(a.loc[i, 'file']).replace('Data_Bach_Nick', 'DATASET')
a.to_csv('DATASET/all.csv', index=False)
