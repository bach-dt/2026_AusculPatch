# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import pandas as pd
import glob
from scipy.signal import find_peaks
import math
from scipy.optimize import curve_fit
from sympy import symbols, solve
import glob
from scipy.signal import find_peaks
import seaborn as sns

# %%
a = pd.read_csv('Fig3e_data.csv', skiprows=9, skipfooter=1)
fs = 85
resistance = a.iloc[60*fs:, 2]
resistance = np.array(resistance)
t = np.linspace(0, len(resistance) / fs, len(resistance))
# resistance = resistance - np.mean(resistance)
plt.figure(figsize=(12, 3))
plt.plot(t, resistance, color='#292929')
plt.xscale('log')
# Out:
# C:\Users\bachd\AppData\Local\Temp\ipykernel_3268\2353689197.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   a = pd.read_csv('Fig3e_data.csv', skiprows=9, skipfooter=1)
