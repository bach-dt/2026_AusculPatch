# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob
from scipy import signal
import math
# from scipy.signal import find_peaks
from scipy.interpolate import make_interp_spline
import matplotlib.patches as patches
from scipy.signal import savgol_filter

# %%
plt.clf()
plt.figure(figsize=[5, 1.75], dpi=500, frameon=False)
plt.locator_params(axis='y', nbins=4)
plt.locator_params(axis='x', nbins=4)
plt.xlim([0, 300])
plt.ylim([-2.5, 22.5])
plt.yticks([0, 10, 20])
a = pd.read_csv('Fig3i1_data.csv')
plt.plot(a['time (s)'], a['Fixed cantilever (delta R(Ohm))'], color='#FF0040', linewidth=1.5, label='Free-standing cantilever')
plt.plot(a['time (s)'], a['Free-standing cantilever (delta R(Ohm))'], color='#3B3B3B', linewidth=1.5, label='Fixed cantilever')

# %%
plt.clf()
plt.figure(figsize=[5, 1.75], dpi=500, frameon=False)
plt.locator_params(axis='y', nbins=4)
plt.locator_params(axis='x', nbins=4)
plt.xlim([0, 300])
plt.ylim([-2.5, 22.5])
plt.yticks([0, 10, 20])
a = pd.read_csv('Fig3i2_data.csv')
plt.plot(a['time (s)'], a['20Pa cyclic test (delta R(Ohm))'], color='#FF0040', linewidth=1.5, label='Free-standing cantilever')
plt.plot(a['time (s)'], a['No pressure (delta R(Ohm))'], color='#3B3B3B', linewidth=1.5, label='Fixed cantilever')

# %%
plt.clf()
plt.figure(figsize=[5, 1.75], dpi=500, frameon=False)
plt.locator_params(axis='y', nbins=4)
plt.locator_params(axis='x', nbins=4)
plt.xlim([0, 300])
plt.ylim([-2.5, 22.5])
plt.yticks([0, 10, 20])
a = pd.read_csv('Fig3k1_data.csv')
plt.plot(a['time (s)'], a['No compensation (V)'], color='#FF0040', linewidth=1.5, label='Free-standing cantilever')

# %%
plt.clf()
plt.figure(figsize=[5, 1.75], dpi=500, frameon=False)
plt.locator_params(axis='y', nbins=4)
plt.locator_params(axis='x', nbins=4)
plt.xlim([0, 300])
plt.ylim([-2.5, 22.5])
plt.yticks([0, 10, 20])
a = pd.read_csv('Fig3k2_data.csv')
plt.plot(a['time (s)'], a['Compensation (V)'], color='#FF0040', linewidth=1.5, label='Free-standing cantilever')
