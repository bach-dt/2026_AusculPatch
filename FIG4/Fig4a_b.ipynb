# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import pandas as pd
import glob
from scipy.signal import find_peaks
import math
from scipy.optimize import curve_fit
from sympy import symbols, solve
import glob
from scipy.signal import find_peaks
import seaborn as sns

# %%
a = pd.read_csv('Fig4a_data.csv')
plt.figure(figsize=[7.5, 1.5], dpi=500)
f = np.array(a['Amplitude(a.u.)'])
t = np.array(a['time(s)'])
plt.xlabel('time(s)')
# plt.ylim(-1, 3)
plt.plot(t, f, '-', color=sns.color_palette("Reds")[4], linewidth=1)

# %%
a = pd.read_csv('Fig4f_g_data.csv')
a = a[a['Subject'] == '#3']
a['time(s)']
plt.xlim(0, 30)
plt.plot(a['time(s)'], a['Amplitude(a.u.)'], '-', color=sns.color_palette("Reds")[4], linewidth=1)

# %%
a = pd.read_csv('Fig4h_data.csv')
plt.plot(a['time(s)'], a['Heart Interval ECG (s)'], '-', color=sns.color_palette("Reds")[4], linewidth=1)
plt.plot(a['time(s)'], a['Heart Interval AusculPatch (s)'], 'o', color=sns.color_palette("Reds")[4], markersize=3)
plt.plot(a['time(s)'], a['Heart Rate ECG (bpm)'], '-', color=sns.color_palette("Reds")[4], linewidth=1)
plt.plot(a['time(s)'], a['Heart Rate AusculPatch (bpm)'], 'o', color=sns.color_palette("Reds")[4], markersize=3)
