# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob
from scipy.signal import find_peaks
import math
from scipy import signal

# %%
a = pd.read_csv('Fig5hij_data.csv')
fs = 900
t = np.array(a['Time (minutes)'])*60
s = np.array(a['Heart Rate Stethoscope (bpm)'])
t = t[np.isnan(s) == False]
s = s[np.isnan(s) == False]
plt.plot(t/60, s, linewidth=3)
